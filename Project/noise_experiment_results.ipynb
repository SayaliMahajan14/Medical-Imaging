# %%
# !git clone https://github.com/SayaliMahajan14/Medical-Imaging
# %cd Medical-Imaging
# Out:
# Cloning into 'Medical-Imaging'...
# remote: Enumerating objects: 167, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 167 (delta 68), reused 47 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (167/167), 42.05 MiB | 16.27 MiB/s, done.
# Resolving deltas: 100% (68/68), done.
# /content/Medical-Imaging

# %%
# !pip install h5py tqdm matplotlib scipy

# %%
# !pip install tensorflow

# %%
# %matplotlib inline

# %%
# %cd /content/Medical-Imaging/Project
# Out:
# /content/Medical-Imaging/Project

# %%
# %run noise_experiment.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# ...
# Noise sigma = 0.0
# ...
# Reading the data. Please wait...
# Elapsed time: 0.007839 seconds.
#
# Successfully read the data from file!
# Now doing undersampling....
# Elapsed time: 0.089566 seconds.
#
# Successfully undersampled data!
# ...
# Noise sigma = 0.01
# ...
# Reading the data. Please wait...
# Elapsed time: 0.007724 seconds.
#
# Successfully read the data from file!
# Now doing undersampling....
# Elapsed time: 0.076210 seconds.
#
# Successfully undersampled data!
# ...
# Noise sigma = 0.03
# ...
# Reading the data. Please wait...
# Elapsed time: 0.005366 seconds.
#
# Successfully read the data from file!
# Now doing undersampling....
# Elapsed time: 0.084322 seconds.
#
# ...
